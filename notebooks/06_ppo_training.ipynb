# %% [markdown]
# # Supply Chain Gym Environment and PPO Training\nThis notebook shows how to use the `SupplyChainEnv` Gym wrapper and train a PPO agent using stable-baselines3.

# %%
from app.gym_env import SupplyChainEnv\nfrom app.train_ppo import train\n\nenv = SupplyChainEnv(days=10)\nobs = env.reset()\nprint('Initial obs:', obs)\na = env.action_space.sample()\nobs, r, done, info = env.step(a)\nprint('Sample action result:', r, done)\n\n# To train (uncomment to run)\n# train(total_timesteps=5000)
